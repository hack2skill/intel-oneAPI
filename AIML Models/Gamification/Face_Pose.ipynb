# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS']='1'
os.environ['TF_ENABLE_MKL_NATIVE_FORMAT']='1'
os.environ['KMP_BLOCKTIME']='1'
os.environ['KMP_SETTINGS']='1'
os.environ['OMP_NUM_THREADS']='6'
os.environ['KMP_AFFINITY']='granularity=fine,verbose,compact,1,0'

# %%
import tensorflow as tf
tf.config.threading.set_inter_op_parallelism_threads(2) 
tf.config.threading.set_intra_op_parallelism_threads(8)
tf.config.set_soft_device_placement(False)

def get_mkl_enabled_flag():
    mkl_enabled = False
    major_version = int(tf.__version__.split(".")[0])
    minor_version = int(tf.__version__.split(".")[1])
    if major_version >= 2:
        if minor_version < 5:
            from tensorflow.python import _pywrap_util_port
        elif minor_version >= 9:

            from tensorflow.python.util import _pywrap_util_port
            onednn_enabled = int(os.environ.get('TF_ENABLE_ONEDNN_OPTS', '1'))

        else:
            from tensorflow.python.util import _pywrap_util_port
            onednn_enabled = int(os.environ.get('TF_ENABLE_ONEDNN_OPTS', '0'))
        mkl_enabled = _pywrap_util_port.IsMklEnabled() or (onednn_enabled == 1)
    else:
        mkl_enabled = tf.pywrap_tensorflow.IsMklEnabled()
    return mkl_enabled

print ("We are using Tensorflow version", tf.__version__)
print("MKL enabled :", get_mkl_enabled_flag())
# Out:
# We are using Tensorflow version 2.12.0
# MKL enabled : True

# %%
import cv2
import dlib
from time import time
import numpy as np
import matplotlib.pyplot as plt
import pickle as pkl
import sklearnex
from sklearnex import patch_sklearn
patch_sklearn() 
from keras.models import Sequential, load_model
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from sklearnex.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
# %matplotlib inline
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
x, y = pkl.load(open('data/samples.pkl', 'rb'))
print(x.shape, y.shape)
# Out:
# (6288, 2278) (6288, 3)

# %%
roll, pitch, yaw = y[:, 0], y[:, 1], y[:, 2]

print(roll.min(), roll.max(), roll.mean(), roll.std())
print(pitch.min(), pitch.max(), pitch.mean(), pitch.std())
print(yaw.min(), yaw.max(), yaw.mean(), yaw.std())
# Out:
# -46.06486893 43.00866699 -0.52579503197042 5.176231116713095
# -29.88856888 34.09674835 2.584682740273537 7.962828151857226
# -75.55059814 86.84925079 -0.11620588007315523 13.090839183150852

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, test_size=0.5, random_state=42)

print(x_train.shape, y_train.shape)
print(x_val.shape, y_val.shape)
print(x_test.shape, y_test.shape)
# Out:
# (4401, 2278) (4401, 3)
# (943, 2278) (943, 3)
# (944, 2278) (944, 3)

# %%
std = StandardScaler()
std.fit(x_train)
x_train = std.transform(x_train)
x_val = std.transform(x_val)
x_test = std.transform(x_test)

# %%
BATCH_SIZE = 64
EPOCHS = 100

# %%
model = Sequential()
model.add(Dense(units=20, activation='relu', kernel_regularizer='l2', input_dim=x.shape[1]))
model.add(Dense(units=10, activation='relu', kernel_regularizer='l2'))
model.add(Dense(units=3, activation='linear'))

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                45580
#
#  dense_1 (Dense)             (None, 10)                210
#
#  dense_2 (Dense)             (None, 3)                 33
#
# =================================================================
# Total params: 45,823
# Trainable params: 45,823
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
callback_list = [EarlyStopping(monitor='val_loss', patience=25)]
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
hist = model.fit(x=x_train, y=y_train, validation_data=(x_val, y_val), batch_size=BATCH_SIZE, epochs=EPOCHS, callbacks=callback_list)
model.save('models/model.h5')
# Out:
# Epoch 1/100
# 69/69 [==============================] - 1s 4ms/step - loss: 68.3241 - val_loss: 62.8199
# Epoch 2/100
# 69/69 [==============================] - 0s 2ms/step - loss: 46.5274 - val_loss: 42.4882
# Epoch 3/100
# 69/69 [==============================] - 0s 2ms/step - loss: 37.0843 - val_loss: 36.1535
# Epoch 4/100
# 69/69 [==============================] - 0s 2ms/step - loss: 35.5464 - val_loss: 35.8670
# Epoch 5/100
# 69/69 [==============================] - 0s 2ms/step - loss: 34.6326 - val_loss: 36.1763
# Epoch 6/100
# 69/69 [==============================] - 0s 2ms/step - loss: 34.6466 - val_loss: 36.8743
# Epoch 7/100
# 69/69 [==============================] - 0s 2ms/step - loss: 34.0069 - val_loss: 35.4946
# Epoch 8/100
# 69/69 [==============================] - 0s 2ms/step - loss: 33.4251 - val_loss: 34.9538
# Epoch 9/100
# 69/69 [==============================] - 0s 2ms/step - loss: 33.4464 - val_loss: 34.9984
# Epoch 10/100
# 69/69 [==============================] - 0s 2ms/step - loss: 33.7141 - val_loss: 36.3997
# Epoch 11/100
# 69/69 [==============================] - 0s 2ms/step - loss: 33.5752 - val_loss: 33.8590
# Epoch 12/100
# 69/69 [==============================] - 0s 2ms/step - loss: 32.6777 - val_loss: 34.1597
# Epoch 13/100
# 69/69 [==============================] - 0s 2ms/step - loss: 33.3495 - val_loss: 35.1334
# Epoch 14/100
# 69/69 [==============================] - 0s 2ms/step - loss: 33.2501 - val_loss: 35.5363
# Epoch 15/100
# 69/69 [==============================] - 0s 2ms/step - loss: 32.7815 - val_loss: 34.2053
# Epoch 16/100
# 69/69 [==============================] - 0s 2ms/step - loss: 33.7009 - val_loss: 34.2478
# Epoch 17/100
# 69/69 [==============================] - 0s 2ms/step - loss: 32.7438 - val_loss: 34.3913
# Epoch 18/100
# 69/69 [==============================] - 0s 2ms/step - loss: 32.7822 - val_loss: 36.3399
# Epoch 19/100
# 69/69 [==============================] - 0s 2ms/step - loss: 32.7972 - val_loss: 34.6423
# Epoch 20/100
# 69/69 [==============================] - 0s 2ms/step - loss: 32.6121 - val_loss: 33.9442
# Epoch 21/100
# 69/69 [==============================] - 0s 2ms/step - loss: 32.2623 - val_loss: 35.2725
# Epoch 22/100
# 69/69 [==============================] - 0s 2ms/step - loss: 32.3742 - val_loss: 33.4093
# Epoch 23/100
# 69/69 [==============================] - 0s 2ms/step - loss: 32.2683 - val_loss: 33.2901
# Epoch 24/100
# 69/69 [==============================] - 0s 2ms/step - loss: 32.2544 - val_loss: 36.0273
# Epoch 25/100
# 69/69 [==============================] - 0s 2ms/step - loss: 32.2510 - val_loss: 35.0505
# Epoch 26/100
# 69/69 [==============================] - 0s 2ms/step - loss: 31.7370 - val_loss: 33.9695
# Epoch 27/100
# 69/69 [==============================] - 0s 2ms/step - loss: 31.7813 - val_loss: 34.1242
# Epoch 28/100
# 69/69 [==============================] - 0s 2ms/step - loss: 31.8195 - val_loss: 35.9742
# Epoch 29/100
# 69/69 [==============================] - 0s 2ms/step - loss: 32.4022 - val_loss: 35.0475
# Epoch 30/100
# 69/69 [==============================] - 0s 2ms/step - loss: 31.7081 - val_loss: 33.8958
# Epoch 31/100
# 69/69 [==============================] - 0s 2ms/step - loss: 31.2188 - val_loss: 34.9174
# Epoch 32/100
# 69/69 [==============================] - 0s 2ms/step - loss: 31.4716 - val_loss: 33.1634
# Epoch 33/100
# 69/69 [==============================] - 0s 2ms/step - loss: 31.3235 - val_loss: 35.8239
# Epoch 34/100
# 69/69 [==============================] - 0s 2ms/step - loss: 31.4200 - val_loss: 33.6449
# Epoch 35/100
# 69/69 [==============================] - 0s 2ms/step - loss: 31.0945 - val_loss: 36.5697
# Epoch 36/100
# 69/69 [==============================] - 0s 2ms/step - loss: 31.4333 - val_loss: 36.2233
# Epoch 37/100
# 69/69 [==============================] - 0s 2ms/step - loss: 31.8166 - val_loss: 36.5551
# Epoch 38/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.9173 - val_loss: 33.0874
# Epoch 39/100
# 69/69 [==============================] - 0s 2ms/step - loss: 31.0512 - val_loss: 34.2354
# Epoch 40/100
# 69/69 [==============================] - 0s 2ms/step - loss: 31.0986 - val_loss: 34.4018
# Epoch 41/100
# 69/69 [==============================] - 0s 2ms/step - loss: 31.6033 - val_loss: 33.6331
# Epoch 42/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.3256 - val_loss: 32.7893
# Epoch 43/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.4783 - val_loss: 33.8587
# Epoch 44/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.8849 - val_loss: 34.4867
# Epoch 45/100
# 69/69 [==============================] - 0s 2ms/step - loss: 31.2534 - val_loss: 35.5173
# Epoch 46/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.8311 - val_loss: 34.6072
# Epoch 47/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.5149 - val_loss: 32.5085
# Epoch 48/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.4549 - val_loss: 34.1871
# Epoch 49/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.3874 - val_loss: 32.6059
# Epoch 50/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.3547 - val_loss: 32.6229
# Epoch 51/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.9353 - val_loss: 33.5689
# Epoch 52/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.5868 - val_loss: 33.5464
# Epoch 53/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.9701 - val_loss: 35.9890
# Epoch 54/100
# 69/69 [==============================] - 0s 3ms/step - loss: 30.3153 - val_loss: 32.5210
# Epoch 55/100
# 69/69 [==============================] - 0s 2ms/step - loss: 29.9038 - val_loss: 33.1743
# Epoch 56/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.5469 - val_loss: 33.4463
# Epoch 57/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.2288 - val_loss: 34.3841
# Epoch 58/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.1330 - val_loss: 32.8229
# Epoch 59/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.2327 - val_loss: 33.6980
# Epoch 60/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.2616 - val_loss: 38.1808
# Epoch 61/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.6853 - val_loss: 32.0963
# Epoch 62/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.1351 - val_loss: 31.7932
# Epoch 63/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.4233 - val_loss: 32.2747
# Epoch 64/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.3927 - val_loss: 34.2562
# Epoch 65/100
# 69/69 [==============================] - 0s 2ms/step - loss: 29.9894 - val_loss: 34.2961
# Epoch 66/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.0108 - val_loss: 35.5102
# Epoch 67/100
# 69/69 [==============================] - 0s 2ms/step - loss: 29.8834 - val_loss: 31.6917
# Epoch 68/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.0173 - val_loss: 35.1851
# Epoch 69/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.0289 - val_loss: 31.8245
# Epoch 70/100
# 69/69 [==============================] - 0s 2ms/step - loss: 29.6041 - val_loss: 33.0721
# Epoch 71/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.1057 - val_loss: 31.3962
# Epoch 72/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.1693 - val_loss: 32.1442
# Epoch 73/100
# 69/69 [==============================] - 0s 2ms/step - loss: 29.9260 - val_loss: 31.9411
# Epoch 74/100
# 69/69 [==============================] - 0s 2ms/step - loss: 29.1159 - val_loss: 31.3792
# Epoch 75/100
# 69/69 [==============================] - 0s 2ms/step - loss: 29.6466 - val_loss: 35.0331
# Epoch 76/100
# 69/69 [==============================] - 0s 2ms/step - loss: 29.7218 - val_loss: 31.3682
# Epoch 77/100
# 69/69 [==============================] - 0s 2ms/step - loss: 29.1586 - val_loss: 33.9432
# Epoch 78/100
# 69/69 [==============================] - 0s 2ms/step - loss: 29.8338 - val_loss: 32.5857
# Epoch 79/100
# 69/69 [==============================] - 0s 2ms/step - loss: 29.5111 - val_loss: 31.5970
# Epoch 80/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.4022 - val_loss: 32.7350
# Epoch 81/100
# 69/69 [==============================] - 0s 2ms/step - loss: 29.2597 - val_loss: 32.5283
# Epoch 82/100
# 69/69 [==============================] - 0s 2ms/step - loss: 29.3087 - val_loss: 31.4004
# Epoch 83/100
# 69/69 [==============================] - 0s 2ms/step - loss: 29.8654 - val_loss: 31.6473
# Epoch 84/100
# 69/69 [==============================] - 0s 2ms/step - loss: 29.2285 - val_loss: 31.9813
# Epoch 85/100
# 69/69 [==============================] - 0s 2ms/step - loss: 29.6811 - val_loss: 32.5350
# Epoch 86/100
# 69/69 [==============================] - 0s 2ms/step - loss: 29.1981 - val_loss: 31.8318
# Epoch 87/100
# 69/69 [==============================] - 0s 2ms/step - loss: 29.4029 - val_loss: 30.9297
# Epoch 88/100
# 69/69 [==============================] - 0s 2ms/step - loss: 29.6895 - val_loss: 31.9405
# Epoch 89/100
# 69/69 [==============================] - 0s 2ms/step - loss: 29.0099 - val_loss: 32.2062
# Epoch 90/100
# 69/69 [==============================] - 0s 2ms/step - loss: 30.1067 - val_loss: 32.2787
# Epoch 91/100
# 69/69 [==============================] - 0s 2ms/step - loss: 29.7998 - val_loss: 31.6650
# Epoch 92/100
# 69/69 [==============================] - 0s 2ms/step - loss: 28.8391 - val_loss: 30.4829
# Epoch 93/100
# 69/69 [==============================] - 0s 2ms/step - loss: 28.9662 - val_loss: 33.5106
# Epoch 94/100
# 69/69 [==============================] - 0s 2ms/step - loss: 29.3137 - val_loss: 31.0555
# Epoch 95/100
# 69/69 [==============================] - 0s 2ms/step - loss: 28.8064 - val_loss: 31.0825
# Epoch 96/100
# 69/69 [==============================] - 0s 2ms/step - loss: 29.0861 - val_loss: 32.2770
# Epoch 97/100
# 69/69 [==============================] - 0s 2ms/step - loss: 28.9162 - val_loss: 32.3818
# Epoch 98/100
# 69/69 [==============================] - 0s 2ms/step - loss: 28.8548 - val_loss: 31.5460
# Epoch 99/100
# 69/69 [==============================] - 0s 2ms/step - loss: 29.4596 - val_loss: 32.6364
# Epoch 100/100
# 69/69 [==============================] - 0s 2ms/step - loss: 28.9501 - val_loss: 31.4530

# %%
print('Train loss:', model.evaluate(x_train, y_train, verbose=0))
print('  Val loss:', model.evaluate(x_val, y_val, verbose=0))
print(' Test loss:', model.evaluate(x_test, y_test, verbose=0))
# Out:
# Train loss: 29.732118606567383
#   Val loss: 31.45303726196289
#  Test loss: 41.27518081665039

# %%
history = hist.history
loss_train = history['loss']
loss_val = history['val_loss']

plt.figure()
plt.plot(loss_train, label='train')
plt.plot(loss_val, label='val_loss', color='red')
plt.legend()

# %%
y_pred = model.predict(x_test)
diff = y_test - y_pred
diff_roll = diff[:, 0]
diff_pitch = diff[:, 1]
diff_yaw = diff[:, 2]

plt.figure(figsize=(16, 10))

plt.subplot(3, 1, 1)
plt.plot(diff_roll, color='red')
plt.title('roll')

plt.subplot(3, 1, 2)
plt.plot(diff_pitch, color='red')
plt.title('pitch')

plt.subplot(3, 1, 3)
plt.plot(diff_yaw, color='red')
plt.title('yaw')

plt.tight_layout()
# Out:
# 30/30 [==============================] - 0s 673us/step

# %%
def detect_face_points(image):
    detector = dlib.get_frontal_face_detector()
    predictor = dlib.shape_predictor("models/shape_predictor_68_face_landmarks.dat")
    face_rect = detector(image, 1)
    if len(face_rect) != 1: return []
    
    dlib_points = predictor(image, face_rect[0])
    face_points = []
    for i in range(68):
        x, y = dlib_points.part(i).x, dlib_points.part(i).y
        face_points.append(np.array([x, y]))
    return face_points
        
def compute_features(face_points):
    assert (len(face_points) == 68), "len(face_points) must be 68"
    
    face_points = np.array(face_points)
    features = []
    for i in range(68):
        for j in range(i+1, 68):
            features.append(np.linalg.norm(face_points[i]-face_points[j]))
            
    return np.array(features).reshape(1, -1)

# %%
im = cv2.imread('data/lena.png', cv2.IMREAD_COLOR)
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
face_points = detect_face_points(im)

for x, y in face_points:
    cv2.circle(im, (x, y), 1, (0, 255, 0), -1)
    
features = compute_features(face_points)
features = std.transform(features)

model = load_model('models/model.h5')
y_pred = model.predict(features)

roll_pred, pitch_pred, yaw_pred = y_pred[0]
print(' Roll: {:.2f}°'.format(roll_pred))
print('Pitch: {:.2f}°'.format(pitch_pred))
print('  Yaw: {:.2f}°'.format(yaw_pred))
    
plt.figure(figsize=(10, 10))
plt.imshow(im)
# Out:
# 1/1 [==============================] - 0s 43ms/step
#  Roll: 6.20°
# Pitch: -7.46°
#   Yaw: 28.84°
