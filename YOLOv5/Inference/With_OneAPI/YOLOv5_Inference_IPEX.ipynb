# %%
# %cd yolov5
# Out:
# /home/u196253/H2S/YOLOv5/Inference/With_OneAPI/yolov5

# %%
pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.6/612.6 kB 3.0 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python yolov5/val.py --weights yolov5/model/best.pt --data /home/u196253/H2S/YOLOv5/Inference/With_OneAPI/yolov5/dataset/data.yaml --img 640
# Out:
# val: data=/home/u196253/H2S/YOLOv5/Inference/With_OneAPI/yolov5/dataset/data.yaml, weights=['yolov5/model/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=cpu, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=yolov5/runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-187-g0004c74 Python-3.9.16 torch-2.0.1+cu117 CPU
#
# Fusing layers...
# custom_YOLOv5s summary: 182 layers, 7270791 parameters, 0 gradients
# val: Scanning /home/u196253/H2S/YOLOv5/Inference/With_OneAPI/yolov5/dataset/vali
# val: WARNING ⚠️ /home/u196253/H2S/YOLOv5/Inference/With_OneAPI/yolov5/dataset/valid/images/b1d0091f-f2c2d2ae_jpg.rf.b0a3b8ba7ad1af007d89ff1ac8c9fd03.jpg: 20 duplicate labels removed
# ...

# %% [markdown]
# # Inference on NightTime Video

# %%
# !python detect.py --weights model/best.pt --img 640 --conf 0.10 --source dataset/NightTimeVideo.mp4
# Out:
# detect: weights=['model/best.pt'], source=dataset/NightTimeVideo.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-187-g0004c74 Python-3.9.16 torch-2.0.1+cu117 CPU
#
# Fusing layers...
# custom_YOLOv5s summary: 182 layers, 7270791 parameters, 0 gradients
# video 1/1 (1/900) /home/u196253/H2S/YOLOv5/Inference/With_OneAPI/yolov5/dataset/NightTimeVideo.mp4: 384x640 (no detections), 74.3ms
# video 1/1 (2/900) /home/u196253/H2S/YOLOv5/Inference/With_OneAPI/yolov5/dataset/NightTimeVideo.mp4: 384x640 (no detections), 45.9ms
# ...

# %% [markdown]
# # Inference on DayTime Video

# %%
# !python detect.py --weights model/best.pt --img 640 --conf 0.10 --source dataset/DayTimeVideo.mp4
# Out:
# video 1/1 (270/900) /home/u196253/H2S/YOLOv5/Inference/With_OneAPI/yolov5/dataset/DayTimeVideo.mp4: 384x640 14 cars, 6 persons, 18 traffic lights, 5 traffic signs, 44.2ms
# video 1/1 (271/900) /home/u196253/H2S/YOLOv5/Inference/With_OneAPI/yolov5/dataset/DayTimeVideo.mp4: 384x640 15 cars, 5 persons, 18 traffic lights, 4 traffic signs, 40.6ms
# video 1/1 (272/900) /home/u196253/H2S/YOLOv5/Inference/With_OneAPI/yolov5/dataset/DayTimeVideo.mp4: 384x640 17 cars, 7 persons, 20 traffic lights, 7 traffic signs, 43.7ms
# video 1/1 (273/900) /home/u196253/H2S/YOLOv5/Inference/With_OneAPI/yolov5/dataset/DayTimeVideo.mp4: 384x640 17 cars, 7 persons, 19 traffic lights, 5 traffic signs, 43.2ms
# video 1/1 (274/900) /home/u196253/H2S/YOLOv5/Inference/With_OneAPI/yolov5/dataset/DayTimeVideo.mp4: 384x640 21 cars, 4 persons, 15 traffic lights, 4 traffic signs, 41.2ms
# ...

# %% [markdown]
# # Inference on Rainy Video

# %%
# !python detect.py --weights model/best.pt --img 640 --conf 0.10 --source dataset/RainyVideo.mp4
# Out:
# detect: weights=['model/best.pt'], source=dataset/RainyVideo.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-187-g0004c74 Python-3.9.16 torch-2.0.1+cu117 CPU
#
# Fusing layers...
# custom_YOLOv5s summary: 182 layers, 7270791 parameters, 0 gradients
# video 1/1 (1/902) /home/u196253/H2S/YOLOv5/Inference/With_OneAPI/yolov5/dataset/RainyVideo.mp4: 384x640 32 cars, 5 traffic lights, 1 traffic sign, 73.7ms
# video 1/1 (2/902) /home/u196253/H2S/YOLOv5/Inference/With_OneAPI/yolov5/dataset/RainyVideo.mp4: 384x640 34 cars, 5 traffic lights, 1 traffic sign, 53.9ms
# ...
