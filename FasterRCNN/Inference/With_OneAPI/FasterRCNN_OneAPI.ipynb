# %%
# %cd /home/u196253/H2S/FasterRCNN/Training/With_OneAPI/fastercnn-pytorch-training-pipeline
# Out:
# /home/u196253/H2S/FasterRCNN/Training/With_OneAPI/fastercnn-pytorch-training-pipeline

# %%
# %%writefile data_configs/custom_data.yaml
# # Images and labels direcotry should be relative to train.py
# TRAIN_DIR_IMAGES: '/home/u196253/H2S/FasterRCNN/Inference/With_OneAPI/fastercnn-pytorch-training-pipeline/dataset/train'
# TRAIN_DIR_LABELS: '/home/u196253/H2S/FasterRCNN/Inference/With_OneAPI/fastercnn-pytorch-training-pipeline/dataset/train'
# VALID_DIR_IMAGES: '/home/u196253/H2S/FasterRCNN/Inference/With_OneAPI/fastercnn-pytorch-training-pipeline/dataset/valid'
# VALID_DIR_LABELS: '/home/u196253/H2S/FasterRCNN/Inference/With_OneAPI/fastercnn-pytorch-training-pipeline/dataset/valid'
#
# # Class names.
# CLASSES: [
#     '__background__',
#     'bike', 'bus', 'car', 'motor', 'person', 'rider', 'traffic light', 'traffic sign', 'train', 'truck'
#     ]
#
# # Number of classes (object classes + 1 for background class in Faster RCNN).
# NC: 11
#
# # Whether to save the predictions of the validation set while training.
# SAVE_VALID_PREDICTION_IMAGES: True
# Out:
# Overwriting data_configs/custom_data.yaml

# %%
# !python inference_video.py
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)
# Frame: 1, Forward pass FPS: 0.432, Forward pass time: 2.314 seconds, Forward pass + annotation time: 2.315 seconds
# Frame: 2, Forward pass FPS: 0.609, Forward pass time: 1.641 seconds, Forward pass + annotation time: 1.642 seconds
# Frame: 3, Forward pass FPS: 0.596, Forward pass time: 1.677 seconds, Forward pass + annotation time: 1.679 seconds
# Frame: 4, Forward pass FPS: 0.605, Forward pass time: 1.654 seconds, Forward pass + annotation time: 1.655 seconds
# Frame: 5, Forward pass FPS: 0.609, Forward pass time: 1.643 seconds, Forward pass + annotation time: 1.644 seconds
# Frame: 6, Forward pass FPS: 0.608, Forward pass time: 1.645 seconds, Forward pass + annotation time: 1.646 seconds
# Frame: 7, Forward pass FPS: 0.619, Forward pass time: 1.617 seconds, Forward pass + annotation time: 1.618 seconds
# ...
