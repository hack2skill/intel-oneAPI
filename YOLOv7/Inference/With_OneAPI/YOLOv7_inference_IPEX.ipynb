# %% [markdown]
# # Testing model

# %%
# %cd yolov7
# Out:
# /home/u196253/H2S/YOLOv7/Inference/With_OneAPI/yolov7

# %%
# !python test.py --data datasets/data/data.yaml --img 500 --batch 16 --conf 0.001 --iou 0.65 --device cpu --weights best.pt --name yolov7_640_val
# Out:
# Namespace(weights=['best.pt'], data='datasets/data/data.yaml', batch_size=16, img_size=500, conf_thres=0.001, iou_thres=0.65, task='val', device='cpu', single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='runs/test', name='yolov7_640_val', exist_ok=False, no_trace=False, v5_metric=False)
# 2023-06-29 00:44:55,230 - utils.torch_utils - INFO - YOLOR 🚀 8e9f0b7 torch 2.0.1+cu117 CPU
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /home/u196253/.local/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %% [markdown]
# # Inference on rainy video

# %%
# !python detect.py --weights model/best.pt --conf 0.10 --img-size 640 --source dataset/Rainy_Video.mp4 --save-txt
# Out:
# Namespace(weights=['model/best.pt'], source='dataset/Rainy_Video.mp4', img_size=640, conf_thres=0.1, iou_thres=0.45, device='', view_img=False, save_txt=True, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# 2023-06-29 01:12:53,916 - utils.torch_utils - INFO - YOLOR 🚀 8e9f0b7 torch 2.0.1+cu117 CPU
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /home/u196253/.local/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 2023-06-29 01:12:54,564 - utils.torch_utils - INFO - Model Summary: 314 layers, 36530318 parameters, 6194944 gradients, 103.3 GFLOPS
# ...

# %% [markdown]
# # Inference on DayTime video

# %%
# !python detect.py --weights model/best.pt --conf 0.10 --img-size 640 --source dataset/DayTimeVideo.mp4 --save-txt
# Out:
# Namespace(weights=['model/best.pt'], source='dataset/DayTimeVideo.mp4', img_size=640, conf_thres=0.1, iou_thres=0.45, device='', view_img=False, save_txt=True, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# 2023-06-29 01:16:28,969 - utils.torch_utils - INFO - YOLOR 🚀 8e9f0b7 torch 2.0.1+cu117 CPU
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /home/u196253/.local/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 2023-06-29 01:16:29,586 - utils.torch_utils - INFO - Model Summary: 314 layers, 36530318 parameters, 6194944 gradients, 103.3 GFLOPS
# ...

# %% [markdown]
# # Inference on NightTime Video

# %%
# !python detect.py --weights model/best.pt --conf 0.10 --img-size 640 --source dataset/NightTimeVideo.mp4 --save-txt
# Out:
# Namespace(weights=['model/best.pt'], source='dataset/NightTimeVideo.mp4', img_size=640, conf_thres=0.1, iou_thres=0.45, device='', view_img=False, save_txt=True, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# 2023-06-29 01:27:12,972 - utils.torch_utils - INFO - YOLOR 🚀 8e9f0b7 torch 2.0.1+cu117 CPU
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /home/u196253/.local/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 2023-06-29 01:27:17,636 - utils.torch_utils - INFO - Model Summary: 314 layers, 36530318 parameters, 6194944 gradients, 103.3 GFLOPS
# ...
